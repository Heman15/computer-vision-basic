# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img= cv2.imread("C:\\Users\\saini\\Desktop\\images.png")
print(img.shape)
print(type(img))
# Out:
# (161, 312, 3)
# <class 'numpy.ndarray'>

# %%
plt.imshow(img)

# %%
img_copy =np.copy(img)
img_copy = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
plt.imshow(img_copy)

# %%
lower_blue = np.array([0, 0, 200])
upper_blue = np.array([200,200,255])
mask = cv2.inRange(img_copy , lower_blue ,upper_blue)
plt.imshow(mask, cmap = 'gray')

# %%
masked_img = np.copy(img_copy)
masked_img[mask != 0]= [0,0,0]
plt.imshow(masked_img)

# %%
bg_image = cv2.imread("C:\\Users\\saini\\Pictures\\Hyderabad-20200226T054755Z-001\\Hyderabad\\DSC_1053.JPG")
bg_image = cv2.cvtColor(bg_image, cv2.COLOR_BGR2RGB)
crop_image = bg_image[0:161, 0:312]
plt.imshow(crop_image)

# %%
crop_image[mask ==0] =[0,0,0]
plt.imshow(crop_image)

# %%
completed = masked_img +crop_image
plt.imshow(completed)
